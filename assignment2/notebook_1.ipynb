# %% [markdown]
# # Assignment 2

# %% [markdown]
# ## Julia Szczepaniak 3 h
# ## Binsha Binsha Nazar Othupalliparambu Nazar

# %% [markdown]
# ### Task 1

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### a) Find a linear regression model that relates the living area to the selling price. If you did any data cleaning step(s), describe what you did and explain why.

# %%
df = pd.read_csv('data_assignment2.csv') # Read data set
x = df.Living_area
y = df.Selling_price
df
# Out:
#     ID  Living_area  Rooms  Land_size  Biarea  Age  Selling_price
# 0    1          104    5.0      271.0    25.0   33        4600000
# 1    2           99    5.0     1506.0     6.0   88        4450000
# 2    3          133    6.0      486.0     NaN   44        4900000
# 3    4          175    7.0      728.0     NaN   14        6625000
# 4    5          118    6.0     1506.0     NaN   29        4600000
# 5    6          133    6.0      823.0     NaN   12        6650000
# 6    7           70    4.0     1685.0    70.0   53        2800000
# 7    8          134    6.0     1593.0    49.0   57        6100000
# 8    9           70    5.0     1120.0   102.0   81        3000000
# 9   10          133    6.0     1503.0     NaN   51        3000000
# 10  11          121    4.0     1575.0   112.0   81        4000000
# 11  12          136    6.0      381.0     NaN   42        4350000
# 12  13           86    4.0     1529.0    30.0   90        3025000
# ...

# %% [markdown]
# We can easily read all of the data. There are no missing values or anomalies; there's no need to filter data.

# %%
model = LinearRegression() # Choose a model
model.fit(x[:, np.newaxis], y) # Find the coefficients for the equation
xfit = np.linspace(50, 230, 1000) # 1000 evenly spaced points in [50, 230].
yfit = model.predict(xfit[:, np.newaxis]) # Extrapolate values of y for the equation

plt.scatter(x, y) # Draw scatter plot
plt.plot(xfit, yfit) # Draw the line graph
plt.title('Relation between the living area and the selling price')
plt.xlabel('Living area')
plt.ylabel('Selling price')
plt.show()
# Out:
# C:\Users\2000j\AppData\Local\Temp\ipykernel_5536\2833071353.py:2: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   model.fit(x[:, np.newaxis], y) # Find the coefficients for the equation

# %% [markdown]
# #### b) Slope and intercept of the line

# %%
# Slope of the line
model.coef_
# Out:
# array([19370.13854733])

# %%
#Intercept of the line:
model.intercept_
# Out:
# 2220603.243355869

# %% [markdown]
# #### c) Predicted values

# %%
model.predict([[10]])
# Out:
# array([2414304.62882918])

# %%
model.predict([[100]])
# Out:
# array([4157617.09808903])

# %%
model.predict([[150]])
# Out:
# array([5126124.02545561])

# %%
model.predict([[200]])
# Out:
# array([6094630.95282218])

# %%
model.predict([[1000]])
# Out:
# array([21590741.79068745])

# %% [markdown]
# #### d) A residual plot

# %%
yPredicted = model.predict(x[:, np.newaxis]) # Calculate predicted values of y by the model
for j in range(len(x)):
    lineXdata = (x[j], x[j])
    lineYdata = (y[j], yPredicted[j])
    plt.plot(lineXdata, lineYdata) # Draw line from the real value to the predicted value for every real value
plt.scatter(x, y) # Draw real points
plt.plot(xfit, yfit) # Draw the line
plt.title('Relation between the living area and the selling price')
plt.xlabel('Living area')
plt.ylabel('Selling price')
plt.show()
# Out:
# C:\Users\2000j\AppData\Local\Temp\ipykernel_5536\3975391366.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   yPredicted = model.predict(x[:, np.newaxis]) # Calculate predicted values of y by the model

# %% [markdown]
# In this case linear regression is not a very useful model but for other areas it might be more suitable. Generally it is useful only if there is a linear (or similar) corellation between data. We could remove values deviating from the average to improve the model's ability to predict selling prices.

# %% [markdown]
# ### Task 2

# %% [markdown]
# ####  a) Visualise the iris data. Can you gain any insights from the visualisation?

# %%
from sklearn.datasets import load_iris
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metric
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_scor

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# From the visualization of the Iris dataset, we can gain several insights:
# The diagonal plots show histograms of each feature and the off diagonal positions shows the scatter plots of different features of iris flower. Scatter plot has distinguishable clusters based on their petal length/width and sepal length/width. So by using a suitable classifier, we are able to identify the species of iris based on the given measurements. Also from the iris dataset there is high difference between the petal length and width while very low difference between sepal length and width. Thus, we can distinguish species using the petal parameters. Another inference is that the scatter plots of three species is quite seperated and can be utilised to analyse the visualize the species. Also, sepal length and width does not seem to be informative in this case.

# %% [markdown]
# ####  b ) Use a confusion matrix to evaluate the use of logistic regression to classify the iris data set.

# %%
X = iris.data
Y = iris.target

X_train,X_test,Y_train,Y_test= train_test_split(X,Y, random_state =0, test_size =0.25)

model = LogisticRegression(solver='liblinear', multi_class='ovr').fit(X_train,Y_train)

# make classification
y_pred = model.predict(X_test)

# calculate model score (accuracy)
score = model.score(X_test, Y_test)

# Create a confusion matrix and plots it
cm = confusion_matrix(Y_test, y_pred, normalize='true')

# plot confusion matrix
fig, ax = plt.subplots(figsize=(9,9))
sns.heatmap(cm, annot = True, fmt=".3f", linewidths=5, square=True, cmap='RdPu' )
ax.set_xticklabels(iris.target_names)
ax.set_yticklabels(iris.target_names)
all_sample_title = 'Confusion matrix \n\nAccuracy Score: {0}'.format(score)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.title(all_sample_title, size = 15)


plt.show()

# %% [markdown]
# On plotting the confusion matrix for the iris data set, we get to know that it has overall 86.8% accuracy. We have 100% accuracy for setosa and virginica but it is only 68.8% for versicolor as 31.2% of it is mispredicted as virginica.

# %% [markdown]
# ####  2 c) Use k-nearest neighbours to classify the iris data set with some different values for k, and with uniform and distance-based weights. What will happen when k grows larger for the different cases? Why does this happen? What doyou think is the best choice of k? Compute a confusion matrix for the best uniform and distance-based classifiers.

# %%
# Creating a for loop that create a plot with different weight and k to illustrate what happens when k grows larger 
# and how it differes between 'distance' and 'uniform'

plt.figure(figsize=(10,10))
plt.xlabel('Number of k')
plt.ylabel('Accuracy Score')
plt.title('Accuracy for different numbers of k', size = 15)

l = list(range(1, 113))
for weight in ['distance','uniform']:
    accuracy_score = [] 
    for i in l:
        # Create KNN Classifier
        knn = KNeighborsClassifier(n_neighbors=i,weights=weight ) 

        #Train the model using the training sets
        knn.fit(X_train, Y_train)

        #Predict the response for test dataset
        y_pred = knn.predict(X_test)

        # Model Accuracy, how often is the classifier correct?
        accuracy_score.append(metrics.accuracy_score(Y_test, y_pred))
        
    
        
    
        
    if weight == 'uniform':
        plt.plot(l,accuracy_score, label = 'Uniform weight', color = 'green')
    else:
        plt.plot(l,accuracy_score, label = 'Distance weight', color = 'blue')

plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
# Perform 10-fold cross-validation for k=1 to 113 for uniform weights
cv_scores_uniform = []
for k in range(1, 113):
    knn = KNeighborsClassifier(n_neighbors=k, weights='uniform')
    scores = cross_val_score(knn, iris.data, iris.target, cv=10)
    cv_scores_uniform.append(scores.mean())

# Perform 10-fold cross-validation for k=1 to 113 for distance-based weights
cv_scores_distance = []
for k in range(1, 113):
    knn = KNeighborsClassifier(n_neighbors=k, weights='distance')
    scores = cross_val_score(knn, iris.data, iris.target, cv=10)
    cv_scores_distance.append(scores.mean())

# Find the best value of k for uniform weights
best_k_uniform = np.argmax(cv_scores_uniform) + 1
print("Best k for uniform weights: {}".format(best_k_uniform))

# Find the best value of k for distance-based weights
best_k_distance = np.argmax(cv_scores_distance) + 1
print("Best k for distance-based weights: {}".format(best_k_distance))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# Here, we plotted the confusion matrix for the best k value for uniform weight and distance wieight classifiers

# %%
#Create KNN Classifier
uniform13 = KNeighborsClassifier(n_neighbors=13,weights='uniform')
# uniform75 = KNeighborsClassifier(n_neighbors=75,weights='uniform')
distance15 = KNeighborsClassifier(n_neighbors=15,weights='distance')
# distance75 = KNeighborsClassifier(n_neighbors=75,weights='distance')

#Train the models using the training sets
for classifier in [uniform13,distance15]:
  classifier.fit(X_train, Y_train)

# predict the response for test datasets
uniform13_predict = uniform13.predict(X_test)

distance15_predict = distance15.predict(X_test)


# model accuracy, how often is the classifier correct?
uniform13_score = uniform13.score(X_test,Y_test)

distance15_score = distance15.score(X_test,Y_test)


# create confusion matrixes
uniform13_cm = confusion_matrix(Y_test, uniform13_predict, normalize = 'true')

distance15_cm = confusion_matrix(Y_test, distance15_predict, normalize = 'true')


# plot confusion matrixes
fig, ((ax1, ax2)) = plt.subplots(1,2, figsize=(10,5))
sns.heatmap(uniform13_cm, ax = ax1, annot = True, fmt=".3f", linewidths=.5, square=True, cmap='RdPu' )

sns.heatmap(distance15_cm, ax = ax2, annot = True, fmt=".3f", linewidths=.5, square=True, cmap='RdPu' )


# set labels
ax1.set_xlabel('Predicted label')
ax1.set_ylabel('Actual label')
ax1.set_title('Uniform weight (k=13) \n Accuracy Score: {0}'.format(uniform13_score), size=10)
ax1.set_xticklabels(iris.target_names)
ax1.set_yticklabels(iris.target_names)

ax2.set_xlabel('Predicted label')
ax2.set_ylabel('Actual label')
ax2.set_title('Distance weight (k=15) \n Accuracy Score: {0}'.format(distance15_score), size=10)
ax2.set_xticklabels(iris.target_names)
ax2.set_yticklabels(iris.target_names)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# ####  c) Compare the logistic regression classifier in (a) with the k-nearest neighbourclassifiers in (b). What do you observe? Are all classes equally challenging for the models to predict?

# %% [markdown]
# Lastly when comparing knn to logistic regression (2a) one could see that knn has a higher accuracy 97% (at least if we use distances weights which vastly outperforms uniform on higher k values) compared to logistic regression which only had a accuracy of 87%.
